# %%
from base_agent import BaseAgent

# %%
from base_agent import BaseAgent

# %%
import os
os.getcwd()
# Out:
# 'e:\\Projects\\Agentic FinTracker\\app\\backend\\agents'

# %%
from chatbot import Chatbot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from chatbot import Chatbot
#
# File e:\Projects\Agentic FinTracker\app\backend\agents\chatbot.py:2
#       1 import json
# ----> 2 from .base_agent import BaseAgent
#       5 class Chatbot(BaseAgent):
#       6     """
#       7     Conversational agent that handles user messages and tool calling.
#       8
#    (...)     20                          - functions_formatter() → returns tool definitions for the API
#      21     """
#
# ImportError: attempted relative import with no known parent package
