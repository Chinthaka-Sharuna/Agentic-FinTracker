# %%
from base_agent import BaseAgent

# %%
from base_agent import BaseAgent

# %%
import os
os.getcwd()
# Out:
# 'E:\\Projects\\1. Ongoing\\Agentic FinTracker\\app\\backend\\agents'

# %%
from chatbot import Chatbot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from chatbot import Chatbot
#
# File E:\Projects\1. Ongoing\Agentic FinTracker\app\backend\agents\chatbot.py:2
#       1 import json
# ----> 2 from .base_agent import BaseAgent
#       5 class Chatbot(BaseAgent):
#       7     def __init__(self,api_key: str,base_url: str = "https://api.openai.com/v1",model: str = "gpt-5-nano",system_prompt: str = "You are a helpful assistant.",tools_obj=None):
#
# ImportError: attempted relative import with no known parent package
