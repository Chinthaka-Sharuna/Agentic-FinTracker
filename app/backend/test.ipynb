# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from backend import DatabaseManager,DBTools,Tools,Config
#
# ImportError: cannot import name 'Config' from 'backend' (E:\Projects\1. Ongoing\Agentic FinTracker\app\backend\__init__.py)
