# %%
import os
os.chdir("D:/Noob Dev/Assessments/01/Agentic FinTracker")

# %%
from app.backend.database.db_manager import DatabaseManager
from app.backend.tools.db_tools import DBTools
from config.config import Config

# %%
db_manager=DatabaseManager(db_path=Config.DATABASE_PATH)
db_tools=DBTools(database_obj=db_manager)

# %%
db_tools.get_expense_summary("2025-01-01","")
# Out:
# get expense summary function
# []
# 'Here is the summary \n []'

# %%
from datetime import date

today = date.today()
last_day = today -
today
# Out:
#   Cell In[5], line 5
#     last_day = today -
#                       ^
# SyntaxError: invalid syntax

# %%
import calendar

year, month = 2024, 2
# monthrange returns (weekday_of_first_day, total_days)
last_day = calendar.monthrange(year, month)

print(f"Last day: {last_day}")

# %%
import calendar
from datetime import date
year, month, day = str(date.today()).split('-')
    last_day = calendar.monthrange(int(year), int(month))[1]
    today=f"{year}-{month}-{day}"
    last_date_of_month=f"{year}-{month}-{last_day}"
    print(today)
    print(last_date_of_month)

# %%
db_tools.get_current_month_date_range()

# %%
print(db_tools.get_total_salry_current_month())
# Out:
# 0
